# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiPrakash4821/offline-pdf-hybrid-/blob/main/Untitled108.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -r requirements.txt
# !apt-get install poppler-utils tesseract-ocr -y
# !pip install pytesseract pdf2image
# !pip install transformers sentence-transformers nltk torch pdfplumber fpdf
# !pip install transformers sentence-transformers fpdf scikit-learn networkx
# !pip install transformers torch
# !pip install PyMuPDF pdf2image pytesseract
import nltk
nltk.download('punkt_tab')
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# poppler-utils is already the newest version (22.02.0-2ubuntu0.12).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# ...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from google.colab import files
uploaded = files.upload()   # upload sai_Preakash_Upated_Resume_1.pdf
# Out:
#      <input type="file" id="files-a2a66bdf-c83b-4210-a950-e26a0ca9523c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a2a66bdf-c83b-4210-a950-e26a0ca9523c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python stage1_extraction.py --pdf "/content/32s44-batch-analysis-rm22-0086.pdf" --out output_colab
# Out:
# Processing: /content/32s44-batch-analysis-rm22-0086.pdf
# /usr/local/lib/python3.12/dist-packages/camelot/parsers/base.py:238: UserWarning: No tables found in table area (143.48789938604838, 135.14047641943804, 180.023648450517, 320.4676204576032)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# ✅ Text file saved: output_colab/32s44-batch-analysis-rm22-0086_extracted.txt
# ✅ JSON file saved: output_colab/32s44-batch-analysis-rm22-0086_extracted.json
# 📊 Tables saved in: output_colab/32s44-batch-analysis-rm22-0086_tables
# ✅ Extraction completed successfully.

# %%
# !python stage2_preprocessing.py --injson "output_colab/32s44-batch-analysis-rm22-0086_extracted.json" --out "output_colab/32s44-batch-analysis-rm22-0086_preprocessed.json"
# Out:
# 2025-11-07 06:22:55.861601: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762496575.928122   21290 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762496575.956526   21290 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762496576.208643   21290 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import os
os.environ['ENABLE_GENERATIVE'] = '1'

# %%
# !python stage3_summarization.py --in "output_colab/32s44-batch-analysis-rm22-0086_preprocessed.json" --outdir output_colab
# Out:
# 2025-11-07 06:24:41.897603: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762496682.005594   21685 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762496682.075946   21685 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762496682.218924   21685 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
#!rm -rf output_colab

# %%
# !git --version
# Out:
# git version 2.34.1

# %%
# !git config --global user.email "your_email@example.com"
# !git config --global user.name "Your Name"

# %%
# 🔁 All-in-one GitHub push from Google Colab

# Step 1: Git config
# !git config --global user.email "your_email@example.com"
# !git config --global user.name "Your Name"

# Step 2: Clone your GitHub repo using a personal access token
# !git clone https://your_token@github.com/your_username/your_repo.git

# Step 3: Move your file(s) into the repo folder
# !mv your_file.ipynb your_repo/

# Step 4: Commit and push
# %cd your_repo
# !git add .
# !git commit -m "Add project from Colab"
# !git push origin main
# Out:
# Cloning into 'your_repo'...
# fatal: could not read Password for 'https://your_token@github.com': No such device or address
# mv: cannot stat 'your_file.ipynb': No such file or directory
# [Errno 2] No such file or directory: 'your_repo'
# /content
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
